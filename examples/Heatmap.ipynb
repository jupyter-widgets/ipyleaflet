# %%
from ipyleaflet import Map, Heatmap
from random import uniform

# %%
m = Map(center=[0, 0], zoom=2)
m

# %%
latlngs = [[uniform(-80, 80), uniform(-180, 180), uniform(0, 1000)] for i in range(1000)] # lat, lng, intensity
heat = Heatmap(latlngs=latlngs, radius=20, blur=10)
m.add_layer(heat)

# %%
heat.radius = 30

# %%
heat.blur = 50

# %%
heat.max = 0.5

# %%
heat.gradient = {0.4: 'red', 0.6: 'yellow', 0.7: 'lime', 0.8: 'cyan', 1.0: 'blue'}

# %%
heat.latlngs = [[uniform(-80, 80), uniform(-180, 180), uniform(0, 1000)] for i in range(1000)]
