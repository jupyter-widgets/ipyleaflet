# %%
import ipyleaflet 
import json 
import pandas as pd
from ipywidgets import link, FloatSlider
from branca.colormap import linear

geo_json_data = json.load(open('us-states.json')) 
m = ipyleaflet.Map(center = (43,-100), zoom = 4)
unemployment = pd.read_csv('US_Unemployment_Oct2012.csv')

# %%
unemployment =  dict(zip(unemployment['State'].tolist(), unemployment['Unemployment'].tolist()))

# %%
layer = ipyleaflet.Choropleth(geo_data=geo_json_data, choro_data=unemployment, colormap=linear.Set1_08, border_color='white')

# %%
m.add_layer(layer)
m

# %%
slider = FloatSlider(min=0, max=10, continuous_update=False)
link((slider, 'value'), (layer, 'value_min'))
slider

# %%
linear.YlOrBr_04.to_step(10)

# %%
linear.RdBu_11

# %%
linear.GnBu_09

# %%
layer.border_color = 'black'
